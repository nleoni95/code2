# %% [raw]
# Afficher vraisemblance et postérieure. Voir si l'approximation est correcte.

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
#inline backend pour voir les figures dans le frontend notebook https://ipython.readthedocs.io/en/stable/interactive/plotting.html
observations=pd.DataFrame(data=np.loadtxt('results/observations.gnu'),columns=['x','obs']) #dataframe qui contient les observations sur lesquelles on travaille
gp=pd.DataFrame(data=np.loadtxt('pg_out.gnu'),columns=['x','mean','std'])
gp_samples=pd.DataFrame(data=np.loadtxt('pg_out.gnu'),columns=['x','mean','std'])

# %%
#Définition du style de plots
plt.style.use('seaborn-white')
# pour la customisation des rcParams : https://matplotlib.org/3.2.0/tutorials/introductory/customizing.html
#print(mpl.rcParams)
mpl.rcParams['axes.labelsize']= 20.0 #def value : 11.0
mpl.rcParams['axes.titlesize']= 20.0 #def value : 12.0
mpl.rcParams['font.size']= 20.0 #def value : 10.0
mpl.rcParams['lines.markersize']= 15.0 #def value : 7.0
mpl.rcParams['lines.linewidth']= 3 #def value : 1.75
mpl.rcParams['legend.fontsize']= 15.0 #def value : 10.0
mpl.rcParams['legend.frameon']= True
mpl.rcParams['text.usetex']= False
mpl.rcParams['xtick.labelsize']= 15.0 #def value : 10.0
mpl.rcParams['xtick.major.size']= 10.0 #taille des ticks
mpl.rcParams['ytick.labelsize']= 15.0 #def value : 10.0
mpl.rcParams['ytick.major.size']= 10.0 #taille des ticks

# %%
#Contourplot de la postérieure. On peut avoir des couleurs continues avec imshow, voir https://jakevdp.github.io/PythonDataScienceHandbook/04.04-density-and-contour-plots.html

ndisc=int(np.sqrt(logp_opti['t1'].size))
xmin=2
xmax=5
ymin=0
ymax=0.04



plt.figure(figsize=[14,14])
ax=plt.subplot(221)
cs=plt.plot('t1','logp',data=logp_opti)
plt.title('Postérieure méthode Opti')
ax.set_xlabel('theta')
ax.set_ylabel('p(theta)')
plt.grid()
ax.set_xlim(xmin,xmax)
ax.set_ylim(ymin,ymax)

ax=plt.subplot(222)
cs=plt.plot('t1','logp',data=logp_koh)
plt.title('Postérieure KOH')
ax.set_xlim(xmin,xmax)
ax.set_ylim(ymin,ymax)

ax.set_xlabel('theta')
ax.set_ylabel('p(theta)')
plt.grid()
ax.set_xlim(xmin,xmax)
ax.set_ylim(ymin,ymax)

ax=plt.subplot(223)
cs=plt.plot('t1','logp',data=logp_plumlee) #on copie les niveaux du plot précédent pour avoir la même échelle de couleurs
plt.title('Postérieure méthode Plumlee')

ax.set_xlabel('theta')
ax.set_ylabel('p(theta)')
plt.grid()
ax.set_xlim(xmin,xmax)
ax.set_ylim(ymin,ymax)

ax=plt.subplot(224)
cs=plt.plot('t1','logp',data=logp_cv) #on copie les niveaux du plot précédent pour avoir la même échelle de couleurs
plt.title('Postérieure cross_validation')

ax.set_xlabel('theta')
ax.set_ylabel('p(theta)')
plt.grid()
ax.set_xlim(xmin,xmax)
ax.set_ylim(ymin,ymax)
# Out:
# (0.0, 0.04)

# %%
def f(x):
    return 4*x+x*np.sin(5*x)

X=np.linspace(0,1,100)

plt.figure(figsize=[6,6])
plt.plot(X,f(X),color='black')
plt.xlabel('x')
plt.ylabel('f(x)')

plt.grid()

# %%
#Contourplot de la postérieure. On peut avoir des couleurs continues avec imshow, voir https://jakevdp.github.io/PythonDataScienceHandbook/04.04-density-and-contour-plots.html

def f(x):
    return 4*x+x*np.sin(5*x)

X=np.linspace(0,1,100)

ndisc=int(np.sqrt(logp_opti['t1'].size))
xmin=2
xmax=5
ymin=0
ymax=0.04

xmin2=0
xmax2=1
ymin2=-2
ymax2=6

print(logp_opti['t1'].std())


plt.figure(figsize=[13,6])



ax=plt.subplot(121)
ax.scatter(x='x',y='obs',label='observations',data=observations,marker='+',linewidth=2,color='tab:purple')
plt.plot(X,f(X),color='black',linewidth=2.5,label='Vérité')
ax.plot('x','fmean',data=pred_opti,label='Prédiction moyenne',color='tab:blue')
ax.fill_between('x','flow','fsup',data=pred_opti,alpha=0.4,color='tab:blue',label='Incertitude paramétrique')
ax.fill_between('x','fsup','fsupsup',data=pred_opti,alpha=0.2,color='tab:blue',label='Erreur de modèle')
ax.fill_between('x','flow','flowlow',data=pred_opti,alpha=0.2,color='tab:blue')
ax.plot('x','fsup',data=pred_opti,color='black',linewidth=0.5,label='')
ax.plot('x','flow',data=pred_opti,color='black',linewidth=0.5,label='')
ax.plot('x','fsupsup',data=pred_opti,color='black',linewidth=0.5,label='')
ax.plot('x','flowlow',data=pred_opti,color='black',linewidth=0.5,label='')
ax.set_xlim(xmin2,xmax2)
ax.set_ylim(ymin2,ymax2)
plt.grid()
plt.legend()
plt.title('Prédictions par méthode Opti')
plt.xlabel('x')
plt.ylabel('f(x)')

ax=plt.subplot(122)
plt.plot(X,f(X),color='black',linewidth=2.5,label='Vérité')


ax.plot('x','fmean',data=pred_cv,label='Prédiction moyenne',color='tab:red')
ax.scatter(x='x',y='obs',label='observations',data=observations,marker='+',linewidth=2,color='tab:purple')
ax.fill_between('x','flow','fsup',data=pred_cv,alpha=0.4,color='tab:red',label='Incertitude paramétrique')
ax.fill_between('x','fsup','fsupsup',data=pred_cv,alpha=0.2,color='tab:red',label='Erreur de modèle')
ax.fill_between('x','flow','flowlow',data=pred_cv,alpha=0.2,color='tab:red')
ax.plot('x','fsup',data=pred_cv,color='black',linewidth=0.5,label='')
ax.plot('x','flow',data=pred_cv,color='black',linewidth=0.5,label='')
ax.plot('x','fsupsup',data=pred_cv,color='black',linewidth=0.5,label='')
ax.plot('x','flowlow',data=pred_cv,color='black',linewidth=0.5,label='')
ax.set_xlim(xmin2,xmax2)
ax.set_ylim(ymin2,ymax2)
plt.grid()
plt.legend()
plt.title('Prédictions par LOO-CV')
plt.xlabel('x')
plt.ylabel('f(x)')
# Out:
# 0.8703447592764606
# Text(0, 0.5, 'f(x)')

# %%
NOBS=np.array([10,20,30,40,50,60,70])
plum=np.array([5.24,2.55,1.74,1.32,1.37,1.52,1.73])
koh=np.array([1.12,1.42,1.90,1.14,1.19,1.18,1.18])
cv=np.array([2824,84,126,54,114,63,41.9])

plt.figure(figsize=[15,6])
ax=plt.subplot(121)
cs=plt.semilogy(NOBS,koh,label='Opti/MaxP',color='tab:orange')
cs=plt.semilogy(NOBS,plum,label='Opti/Plumlee',color='tab:green')
cs=plt.semilogy(NOBS,cv,label='Opti/LOO-CV',color='tab:red')
plt.legend()

plt.title('Comparaison de modèles')
ax.set_xlabel("nombre d'observations")
ax.set_ylabel('facteur de Bayes')
plt.grid()

ax=plt.subplot(122)
cs=plt.plot('t1','logp',data=logp_opti,label='Opti',color='tab:blue')
cs=plt.plot('t1','logp',data=logp_koh,label='MaxP',color='tab:orange')
cs=plt.plot('t1','logp',data=logp_plumlee,label='Plumlee',color='tab:green')
cs=plt.plot('t1','logp',data=logp_cv,label='LOOCV',color='tab:red')
plt.legend()

plt.title('Densités a posteriori')
ax.set_xlabel('theta')
ax.set_ylabel('p(theta)')
plt.grid()
ax.set_xlim(xmin,xmax)
ax.set_ylim(ymin,ymax)
# Out:
# (0.0, 0.04)
