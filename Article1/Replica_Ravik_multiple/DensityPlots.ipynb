# %% [raw]
# Voir à la fin: 29 mars. J'affiche les points de training des hGPs.

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
import seaborn as sns
# %matplotlib inline
import os

# %%
#belles figures pour l'affichage de prédictions.
colorfz='cyan'
colorf='tab:blue'
colorfzkoh='gold'
colorfkoh='tab:orange'
colorffb='tab:green'
colorpri='tab:red'
lw2=2
lw1=2
case=16

# %%
#mcmc_allplot('b')

# %%
#estimation of model error
predoptFZ=pd.DataFrame(data=np.loadtxt(shortprefixe+"predoptFZ.gnu"),columns=['x','ymean','stdf','zmean'])
predkohFZ=pd.DataFrame(data=np.loadtxt(shortprefixe+"predkohFZ.gnu"),columns=['x','ymean','stdf','zmean'])
predmcmcFZ=pd.DataFrame(data=np.loadtxt(shortprefixe+"predmcmcFZ.gnu"),columns=['x','ymean','stdf','zmean'])
print(predkohFZ['zmean'].mean()*25)
print(predoptFZ['zmean'].mean()*25)
print(predmcmcFZ['zmean'].mean()*25)
# Out:
# 2907271.3195625003
# 2850260.05371875
# 2551858.4882343747

# %%
autocor=pd.DataFrame(data=np.loadtxt(shortprefixe+"autocor.gnu"),columns=['t1','t2','t3','edm','exp','lcor'])
fig,ax=plt.subplots(1,1,figsize=(6,6))
ax.plot(autocor['lcor'])
ax.hlines(0,0,1000,color='tab:red')
plt.show()

# %%
# le meilleur des samples ?
print(selected_samples.sort_values(by=['p'],ascending=False).head(20))
# Out:
#             t1        t2        t3       edm       exp      lcor         p
# 941   39.32900  0.000018  0.535612  174880.5  72200.43  12.81053 -95.77321
# 14    33.14688  0.000018  0.565906  218381.6  55334.49  11.72351 -95.78889
# 2838  33.39384  0.000018  0.572117  217463.4  63819.73  11.23996 -95.79233
# 1619  33.21149  0.000019  0.554010  225312.7  71847.88  12.21045 -95.84641
# 1743  33.33595  0.000018  0.556818  238367.0  57524.36  11.52301 -95.86531
# 932   34.52075  0.000019  0.566562  157097.4  64831.29  10.41571 -95.89209
# 1173  32.04752  0.000019  0.575846  169377.0  76220.36  11.59432 -95.89753
# 46    37.82058  0.000017  0.545610  239846.1  62883.57  12.76911 -95.90195
# 2758  37.89039  0.000018  0.537107  253603.9  55315.66  13.29992 -95.90461
# 41    31.41361  0.000019  0.585888  200750.8  71637.07  12.74276 -95.91399
# 2072  40.80500  0.000018  0.533795  225926.9  59698.28  12.05170 -95.92020
# 194   34.66299  0.000017  0.578448  195609.8  61858.72  14.26587 -95.94963
# 896   35.24664  0.000018  0.578654  185830.7  73031.42  14.56251 -95.95619
# 1081  38.17502  0.000017  0.565032  126755.0  67739.26  12.11200 -95.95620
# 2670  37.19745  0.000017  0.570594  228593.1  69745.57  11.81363 -95.96439
# 1358  35.56315  0.000019  0.553617  138353.9  68993.20  12.84125 -95.96456
# 306   38.39495  0.000018  0.522602  245995.7  66453.86  13.17902 -95.97155
# 760   35.34322  0.000017  0.567303  242512.7  70917.66  11.18645 -95.97874
# 1548  33.72919  0.000019  0.547476  199976.3  65735.33  14.59135 -95.98144
# 113   32.94945  0.000017  0.591178  232476.1  65820.55  12.01187 -95.98889

# %%
print(all_samples.query('edm<206912').query('edm>204000').query('exp<62000').query('exp>61000').sort_values(by=['p'],ascending=False).head(20))
# Out:
#                t1        t2        t3       edm       exp      lcor         p
# 1644505  35.34440  0.000018  0.565589  204086.4  61808.27  12.88134 -95.68980
# 1644503  35.34440  0.000018  0.565589  204086.4  61808.27  12.88134 -95.68980
# 1644506  35.34440  0.000018  0.565589  204086.4  61808.27  12.88134 -95.68980
# 1644504  35.34440  0.000018  0.565589  204086.4  61808.27  12.88134 -95.68980
# 1010276  32.20762  0.000018  0.575023  205578.0  61002.60  12.73479 -95.87543
# 1010280  32.20762  0.000018  0.575023  205578.0  61002.60  12.73479 -95.87543
# 1010271  32.20762  0.000018  0.575023  205578.0  61002.60  12.73479 -95.87543
# 1010272  32.20762  0.000018  0.575023  205578.0  61002.60  12.73479 -95.87543
# 1010273  32.20762  0.000018  0.575023  205578.0  61002.60  12.73479 -95.87543
# 1010274  32.20762  0.000018  0.575023  205578.0  61002.60  12.73479 -95.87543
# 1010275  32.20762  0.000018  0.575023  205578.0  61002.60  12.73479 -95.87543
# 1010290  32.20762  0.000018  0.575023  205578.0  61002.60  12.73479 -95.87543
# 1010277  32.20762  0.000018  0.575023  205578.0  61002.60  12.73479 -95.87543
# 1010278  32.20762  0.000018  0.575023  205578.0  61002.60  12.73479 -95.87543
# 1010279  32.20762  0.000018  0.575023  205578.0  61002.60  12.73479 -95.87543
# 1010281  32.20762  0.000018  0.575023  205578.0  61002.60  12.73479 -95.87543
# 1010282  32.20762  0.000018  0.575023  205578.0  61002.60  12.73479 -95.87543
# 1010283  32.20762  0.000018  0.575023  205578.0  61002.60  12.73479 -95.87543
# 1010284  32.20762  0.000018  0.575023  205578.0  61002.60  12.73479 -95.87543
# 1010285  32.20762  0.000018  0.575023  205578.0  61002.60  12.73479 -95.87543

# %%
print(kde.evaluate([162990,66198])) #opti(voir cellule du dessous)
# Out:
# [4.2995564e-11]

# %%
print([hpars_points['edm'].head(1),hpars_points['exp'].head(1)])
# Out:
# [2988    173393.1
# Name: edm, dtype: float64, 2988    68744.6
# Name: exp, dtype: float64]

# %%
print(kde.evaluate([227831,62736])) #koh
# Out:
# [5.81987469e-11]

# %%
print(6.55/5.8)
# Out:
# 1.1293103448275863

# %%
hgp3=pd.DataFrame(np.loadtxt("results/hparsopt/150/hopt3.gnu"),columns=['t1','t2','t3','s','l'])
h1=hgp3.loc[:49]
h2=hgp3.loc[50:74]
h3=hgp3.loc[75:99]
h4=hgp3.loc[100:124]
h5=hgp3.loc[125:149]
h6=hgp3.loc[150:174]
h7=hgp3.loc[175:199]
fig,ax=plt.subplots(figsize=(6,6))
lab1='t1'
lab2='t3'
ax.scatter(h1[lab1],h1[lab2],color='black',label=r'1-50')
ax.scatter(h2[lab1],h2[lab2],color='red',label=r'51-75')
ax.scatter(h3[lab1],h3[lab2],color='blue',label=r'76-100')
ax.scatter(h4[lab1],h4[lab2],color='orange',label=r'101-125')
ax.scatter(h5[lab1],h5[lab2],color='green',label=r'126-150')
ax.legend(fontsize=18,ncol=1,bbox_to_anchor=(1.5,1))
ax.set_xlabel(r'$\theta_1$',fontsize=18)
ax.set_ylabel(r'$\theta_2$',fontsize=18)
ax.set_title(r'Points added in the training of surrogates',fontsize=18)

ax.tick_params(axis='both', labelsize=15)
#ax.scatter(h6[lab1],h6[lab2],color='yellow')
#ax.scatter(h7[lab1],h7[lab2],color='grey')

# %%
#on regarde les samples bayes et FMP. kom je pri. ah j'ai pas écrit les samples bayes lul.
########################### on passe aux densités calibration multiples
colorfz='cyan'
colorf='tab:blue'
colorfzkoh='gold'
colorfkoh='tab:orange'
colorfzfb='springgreen'
colorffb='tab:green'
colorpri='tab:red'
lw2=2
lw1=2
foldname='results/'
foldnamefmp='results/fmp/'
foldnamefb='results/bayes/'
foldnamekoh='results/koh/'
###load dfs
sampfmp=pd.DataFrame(data=np.loadtxt(foldnamefmp+'sample.gnu')[:,:3],columns=[r'$\theta_1$',r'$\theta_2$',r'$\theta_3$'])
sampfb=pd.DataFrame(data=np.loadtxt(foldnamefb+'sample.gnu')[:,:3],columns=[r'$\theta_1$',r'$\theta_2$',r'$\theta_3$'])
sampkoh=pd.DataFrame(data=np.loadtxt(foldnamekoh+'sample.gnu')[:,:3],columns=[r'$\theta_1$',r'$\theta_2$',r'$\theta_3$'])
samppri=pd.DataFrame(data=np.loadtxt('results/priorsamples.gnu')[-len(sampfmp):,:3],columns=[r'$\theta_1$',r'$\theta_2$',r'$\theta_3$'])



sampfmp['Calibration']='FMP'
sampfb['Calibration']='Full Bayes'
sampkoh['Calibration']='KOH'
samppri['Calibration']='Prior'
df=pd.concat([sampfmp,sampfb,sampkoh,samppri],ignore_index=True)
# convertir les colonnes des paramètres dans l'espace réel. valeur ominales : 40, 18.9e-6, 0.75.
df[r'$\theta_1$']=(df[r'$\theta_1$']+0.5)*40
df[r'$\theta_2$']=(df[r'$\theta_2$']+0.5)*18.9E-6
df[r'$\theta_3$']=(df[r'$\theta_3$']+0.5)*0.75

df=df[df[r'$\theta_1$']>0]
df=df[df[r'$\theta_1$']<90]
mpl.rcParams["axes.labelsize"]=18
mpl.rcParams['figure.figsize'] = 6,6
ax=sns.kdeplot(x=r'$\theta_3$',data=df,hue='Calibration',palette={
                    'FMP':colorf,
                    'KOH':colorfkoh,
                    'Full Bayes':colorffb,
                    'Prior':colorpri
                },linewidth=3)
plt.setp(ax.get_legend().get_texts(), fontsize='16') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='18') # for legend title
plt.tick_params(axis='both', labelsize=15)
'''
g = sns.PairGrid(df,hue='Calibration',diag_sharey=False,
                palette={
                    'FMP':colorf,
                    'KOH':colorfkoh,
                    'Full Bayes':colorffb
                    ,'Prior':colorpri
                },
                 height=3,aspect=1
                )
g.map_diag(sns.kdeplot)
axes=g.axes
g.map_upper(sns.kdeplot,levels=2)
g.map_lower(sns.scatterplot,s=1)
g.add_legend()
'''
# Out:
# "\ng = sns.PairGrid(df,hue='Calibration',diag_sharey=False,\n                palette={\n                    'FMP':colorf,\n                    'KOH':colorfkoh,\n                    'Full Bayes':colorffb\n                    ,'Prior':colorpri\n                },\n                 height=3,aspect=1\n                )\ng.map_diag(sns.kdeplot)\naxes=g.axes\ng.map_upper(sns.kdeplot,levels=2)\ng.map_lower(sns.scatterplot,s=1)\ng.add_legend()\n"

# %%
#prédictions avec densités multiples.
colorfz='cyan'
colorf='tab:blue'
colorfzkoh='gold'
colorfkoh='tab:orange'
colorfzfb='springgreen'
colorffb='tab:green'
colorpri='tab:grey'
lw2=2
lw1=2
case=4
#le cas 8 a des observations relou.
foldname='results/'
obs=pd.DataFrame(data=np.loadtxt(foldname+'/obs/obs'+str(case)+'.gnu'),columns=['x','y','incx','incy'])

pfb=pd.DataFrame(data=np.loadtxt(foldname+'bayes/preds'+str(case)+'.gnu'),columns=['x','fzmean','fzstd','fzstd2','fmean','q2p5','q97p5'])
sampFfb=pd.DataFrame(data=np.loadtxt(foldname+'bayes/sampsf'+str(case)+'.gnu'),columns=['x','s1','s2','s3','s4','s5','s6','s7','s8','s9','s10'])
sampZfb=pd.DataFrame(data=np.loadtxt(foldname+'bayes/sampsz'+str(case)+'.gnu'),columns=['x','s1','s2','s3','s4','s5','s6','s7','s8','s9','s10'])

pfmp=pd.DataFrame(data=np.loadtxt(foldname+'fmp/preds'+str(case)+'.gnu'),columns=['x','fzmean','fzstd','fzstd2','fmean','q2p5','q97p5'])
sampFfmp=pd.DataFrame(data=np.loadtxt(foldname+'fmp/sampsf'+str(case)+'.gnu'),columns=['x','s1','s2','s3','s4','s5','s6','s7','s8','s9','s10'])
sampZfmp=pd.DataFrame(data=np.loadtxt(foldname+'fmp/sampsz'+str(case)+'.gnu'),columns=['x','s1','s2','s3','s4','s5','s6','s7','s8','s9','s10'])

pkoh=pd.DataFrame(data=np.loadtxt(foldname+'koh/preds'+str(case)+'.gnu'),columns=['x','fzmean','fzstd','fzstd2','fmean','q2p5','q97p5'])
sampFkoh=pd.DataFrame(data=np.loadtxt(foldname+'koh/sampsf'+str(case)+'.gnu'),columns=['x','s1','s2','s3','s4','s5','s6','s7','s8','s9','s10'])
sampZkoh=pd.DataFrame(data=np.loadtxt(foldname+'koh/sampsz'+str(case)+'.gnu'),columns=['x','s1','s2','s3','s4','s5','s6','s7','s8','s9','s10'])


fig,axs=plt.subplots(nrows=1,ncols=4,figsize=(20,6))



axs=np.reshape(axs,(2,2))
axs[0,0].plot(pfb['x'],sampFfb['s1'],linewidth=1.5,color=colorfzfb,zorder=0,alpha=0.8,label=r'samples of $f+z_{\theta}$')
axs[0,0].plot(pfb['x'],pfb['fmean'],linewidth=lw2,linestyle='-.',color=colorf,label=r'$f(x,\theta_{\mathrm{pmean}})$')
axs[0,0].plot(pfb['x'],pfb['q97p5'],linewidth=lw1,linestyle='--',color=colorf,label=r'95$\%$ credence interval')
axs[0,0].plot(pfb['x'],pfb['q2p5'],linewidth=lw1,linestyle='--',color=colorf)

axs[0,1].plot(pfmp['x'],sampFfmp['s1'],linewidth=1.5,color=colorfz,zorder=0,alpha=0.8,label=r'samples of $f+z_{\theta}$')
axs[0,1].plot(pfmp['x'],pfmp['fmean'],linewidth=lw2,linestyle='-.',color=colorf,label=r'$f(x,\theta_{\mathrm{pmean}})$')
axs[0,1].plot(pfmp['x'],pfmp['q97p5'],linewidth=lw1,linestyle='--',color=colorf,label=r'95$\%$ credence interval')
axs[0,1].plot(pfmp['x'],pfmp['q2p5'],linewidth=lw1,linestyle='--',color=colorf)

axs[1,0].plot(pkoh['x'],sampFkoh['s1'],linewidth=1.5,color=colorfzkoh,zorder=0,alpha=0.8,label=r'samples of $f+z_{\theta}$')
axs[1,0].plot(pkoh['x'],pkoh['fmean'],linewidth=lw2,linestyle='-.',color=colorf,label=r'$f(x,\theta_{\mathrm{pmean}})$')
axs[1,0].plot(pkoh['x'],pkoh['q97p5'],linewidth=lw1,linestyle='--',color=colorf,label=r'95$\%$ credence interval')
axs[1,0].plot(pkoh['x'],pkoh['q2p5'],linewidth=lw1,linestyle='--',color=colorf)


ls=['s1','s2','s3','s4','s5','s6','s7','s8','s9']
#ls=['s5']

for s in ls:
    axs[0,0].plot(pfb['x'],sampFfb[s]+sampZfb[s],linewidth=1.5,color=colorfz,zorder=0,alpha=0.8)
    axs[0,1].plot(pfmp['x'],sampFfmp[s]+sampZfmp[s],linewidth=1.5,color=colorfz,zorder=0,alpha=0.8)
    axs[1,0].plot(pkoh['x'],sampFkoh[s]+sampZkoh[s],linewidth=1.5,color=colorfz,zorder=0,alpha=0.8)

axs[0,0].errorbar(obs['x'],obs['y'],xerr=3*obs['incx'],
             color='black',marker='o',ms=6,mfc='white',
             capsize=5,linewidth=0,elinewidth=2,
             label='observations',zorder=100)

axs[0,1].errorbar(obs['x'],obs['y'],xerr=3*obs['incx'],
             color='black',marker='o',ms=6,mfc='white',
             capsize=5,linewidth=0,elinewidth=2,
             label='observations',zorder=100)
axs[1,1].errorbar(obs['x'],obs['y'],xerr=3*obs['incx'],
             color='black',marker='o',ms=6,mfc='white',
             capsize=5,linewidth=0,elinewidth=2,
             label='observations',zorder=100)

axs[1,0].errorbar(obs['x'],obs['y'],xerr=3*obs['incx'],
             color='black',marker='o',ms=6,mfc='white',
             capsize=5,linewidth=0,elinewidth=2,
             label='observations',zorder=100)

for ax in axs:
    for ax2 in ax:
        ax2.yaxis.offsetText.set_visible(False)

offset = axs[0,0].yaxis.get_major_formatter().get_offset()

axs[0,0].set_xlim([0,35])
axs[0,0].set_ylim([0,obs['y'][len(obs['y'])-1]+3*obs['incy'][len(obs['y'])-1]+1e5])
axs[0,0].set_xlabel('Wall superheat $[K]$ ')
axs[0,0].yaxis.set_label_text(r'Heat flux $[W.m^{-2}] \times 10^6$')
axs[0,0].set_title('FB predictions, case '+str(case),fontsize=25)

axs[0,1].set_xlim([0,35])
axs[0,1].set_ylim([0,obs['y'][len(obs['y'])-1]+3*obs['incy'][len(obs['y'])-1]+1e5])
axs[0,1].set_xlabel('Wall superheat $[K]$')
#axs[1].set_ylabel('Heat flux $[W.m^{-2}]$')
axs[0,1].set_title('FMP predictions, case '+str(case),fontsize=25)

axs[1,1].set_xlim([0,35])
axs[1,1].set_ylim([0,obs['y'][len(obs['y'])-1]+3*obs['incy'][len(obs['y'])-1]+1e5])
axs[1,1].set_xlabel('Wall superheat $[K]$')
#axs[1].set_ylabel('Heat flux $[W.m^{-2}]$')
axs[1,0].set_title('KOH predictions, case '+str(case),fontsize=25)

axs[1,0].set_xlim([0,35])
axs[1,0].set_ylim([0,obs['y'][len(obs['y'])-1]+3*obs['incy'][len(obs['y'])-1]+1e5])
axs[1,0].set_xlabel('Wall superheat $[K]$')
#axs[1].set_ylabel('Heat flux $[W.m^{-2}]$')
axs[1,1].set_title('KOH pooled predictions, case '+str(case),fontsize=25)


#print(obs)
plt.tight_layout()

axs[0,0].legend(ncol=5,bbox_to_anchor=(0.8, 0.03),
          bbox_transform=fig.transFigure)
#print les hpars koh pooled
#ls=['s5']
#cases=['4','5','6','15','18','20','21','22']# ceux qui sont bons.

# %%
#posterior of hyperparameter ? 

#prédictions avec densités multiples.
colorfz='cyan'
colorf='tab:blue'
colorfzkoh='gold'
colorfkoh='tab:orange'
colorfzfb='springgreen'
colorffb='tab:green'
colorpri='tab:orange'
lw2=2
lw1=2
case=6
#prédictions bayes disponibles seulement sur les cas 3,4,6,16,20
#cases=['8']

cases=['4']# ceux qui sont bons.
cases=['4','5','6','15','18','20','21','22']# ceux qui sont bons.
cases=['3','4','5','6','8','14','15','16','18','20','21','22','23']
cases=['3','4','5','6','15','16','18','20','21']
cases=['4','16']

#obligé de faire à la main car on a tout mis dans 1 fichier.
    #le cas 8 a des observations relou.
foldname='results/'
foldnameM2='results/fmp/'
foldnameMkohpooled='results/koh/'
foldnameMfb='results/bayes/'

sampfmp=pd.DataFrame(data=np.loadtxt(foldnameM2+'sample.gnu'),columns=['t1','t2','t3','s3','l3','s4','l4','s5','l5','s6','l6','s15','l15','s16','l16','s18','l18','s20','l20','s21','l21'])
sampbayes=pd.DataFrame(data=np.loadtxt(foldnameMfb+'sample.gnu'),columns=['t1','t2','t3','s3','l3','s4','l4','s5','l5','s6','l6','s15','l15','s16','l16','s18','l18','s20','l20','s21','l21'])
sampkoh=pd.DataFrame(data=np.loadtxt(foldnameMkohpooled+'sample.gnu'),columns=['t1','t2','t3','s3','l3','s4','l4','s5','l5','s6','l6','s15','l15','s16','l16','s18','l18','s20','l20','s21','l21'])

s='s6'
l='l6'

'''
sampfmp[s]=np.log(sampfmp[s])
sampbayes[s]=np.log(sampbayes[s])
sampkoh[s]=np.log(sampkoh[s])

sampfmp[l]=np.log(sampfmp[l])
sampbayes[l]=np.log(sampbayes[l])
sampkoh[l]=np.log(sampkoh[l])
'''
sampfmp['Calibration']='FMP'
sampbayes['Calibration']='Full Bayes'
sampkoh['Calibration']='KOH'
dfhope=pd.concat([sampbayes,sampfmp,sampkoh],ignore_index=True)
fig,axs=plt.subplots(nrows=1,ncols=1,figsize=(6,6))
sns.scatterplot(x=s,y=l,data=dfhope,hue='Calibration',palette={
                'FMP':colorf,
                'Full Bayes':colorffb,
            'KOH':colorfkoh
            })

    
#ls=['s5']
#cases=['4','5','6','15','18','20','21','22']# ceux qui sont bons.

# %%
#FMP prédictions: z et f+z.



#prédictions avec densités multiples.
colorfz='cyan'
colorf='tab:blue'
colorfzkoh='gold'
colorfkoh='tab:orange'
colorfzfb='springgreen'
colorffb='tab:green'
colorpri='tab:grey'
lw2=2
lw1=2
case=6
#le cas 8 a des observations relou.
foldname='results/'
obs=pd.DataFrame(data=np.loadtxt(foldname+'/obs/obs'+str(case)+'.gnu'),columns=['x','y','incx','incy'])


pfmp=pd.DataFrame(data=np.loadtxt(foldname+'fmp/preds'+str(case)+'.gnu'),columns=['x','fzmean','fzstd','fzstd2','fmean','q2p5','q97p5'])
sampFfmp=pd.DataFrame(data=np.loadtxt(foldname+'fmp/sampsf'+str(case)+'.gnu'),columns=['x','s1','s2','s3','s4','s5','s6','s7','s8','s9','s10'])
sampZfmp=pd.DataFrame(data=np.loadtxt(foldname+'fmp/sampsz'+str(case)+'.gnu'),columns=['x','s1','s2','s3','s4','s5','s6','s7','s8','s9','s10'])



fig,axs=plt.subplots(nrows=1,ncols=2,figsize=(10,6))



#axs[1].plot(pfb['x'],sampFfmp['s1'],linewidth=1.5,color='tab:red',zorder=0,alpha=0.8,label=r'samples')
axs[1].plot(pfb['x'],pfmp['fmean'],linewidth=lw2,linestyle='-.',color='tab:blue',label=r'posterior mean')
axs[1].plot(pfb['x'],pfmp['q97p5'],linewidth=lw1,linestyle='--',color='tab:blue',label=r'95$\%$ credible interval')
axs[1].plot(pfb['x'],pfmp['q2p5'],linewidth=lw1,linestyle='--',color='tab:blue')
axs[1].fill_between(pfb['x'],pfmp['q2p5'],pfmp['q97p5'],color='tab:blue',alpha=0.3)


#axs[0].plot(pfmp['x'],sampFfmp['s1'],linewidth=1.5,color='tab:red',zorder=0,alpha=0.8,label=r'samples')
axs[0].plot(pfmp['x'],pfmp['fzmean'],linewidth=lw2,linestyle='-.',color='tab:blue',label=r'posterior mean')
axs[0].plot(pfmp['x'],pfmp['fzmean']+2*pfmp['fzstd'],linewidth=lw1,linestyle='--',color='tab:blue',label=r'95$\%$ credible interval')
axs[0].plot(pfmp['x'],pfmp['fzmean']-2*pfmp['fzstd'],linewidth=lw1,linestyle='--',color='tab:blue')

axs[0].fill_between(pfmp['x'],pfmp['fzmean']-2*pfmp['fzstd'],pfmp['fzmean']+2*pfmp['fzstd'],color='tab:blue',alpha=0.3)

ls=['s4','s5','s6']
#ls=['s5']

#for s in ls:
#    axs[1].plot(pfb['x'],sampFfmp[s],linewidth=1.5,color='tab:red',zorder=0,alpha=0.3)
#    axs[0].plot(pfmp['x'],sampFfmp[s]+sampZfmp[s],linewidth=1.5,color='tab:red',zorder=0,alpha=0.3)
 
axs[0].errorbar(obs['x'],obs['y'],xerr=3*obs['incx'],
             color='tab:red',marker='o',ms=6,mfc='white',
             capsize=5,capthick=3,linewidth=0,elinewidth=3,
             label='observations',zorder=100)

axs[1].errorbar(obs['x'],obs['y'],xerr=3*obs['incx'],
             color='tab:red',marker='o',ms=6,mfc='white',
             capsize=5,capthick=3,linewidth=0,elinewidth=3,
             label='observations',zorder=100)

for ax2 in axs:
    ax2.yaxis.offsetText.set_visible(False)

offset = axs[0].yaxis.get_major_formatter().get_offset()

axs[0].set_xlim([0,35])
axs[0].set_ylim([0,obs['y'][len(obs['y'])-1]+3*obs['incy'][len(obs['y'])-1]+1e6])
axs[0].set_xlabel('Wall superheat $[K]$ ')
axs[0].yaxis.set_label_text(r'Heat flux $[W.m^{-2}] \times 10^6$')
axs[0].set_title('Predictions with \n'+r'$f+z_\theta$, case '+str(case),fontsize=25)

axs[1].set_xlim([0,35])
axs[1].set_ylim([0,obs['y'][len(obs['y'])-1]+3*obs['incy'][len(obs['y'])-1]+1e6])
axs[1].set_xlabel('Wall superheat $[K]$')
#axs[1].set_ylabel('Heat flux $[W.m^{-2}]$')
axs[1].set_title('Predictions with \n'+r'$f$, case '+str(case),fontsize=25)
#print(obs)

nom=pd.DataFrame(data=np.loadtxt('results/cnom'+str(case)+'.gnu'),columns=['x','pred'])
axs[1].plot(nom['x'],nom['pred'],linestyle='-',color='black',label='without calibration',lw=2)
plt.tight_layout()


axs[0].legend(fontsize=15)
axs[1].legend(fontsize=15)
#print les hpars koh pooled
#ls=['s5']
#cases=['4','5','6','15','18','20','21','22']# ceux qui sont bons.

axs[0].tick_params(axis='both', labelsize=20)
axs[1].tick_params(axis='both', labelsize=20)

# %%
#FMP prédictions: z et f+z.



#prédictions avec densités multiples.
colorfz='cyan'
colorf='tab:blue'
colorfzkoh='gold'
colorfkoh='tab:orange'
colorfzfb='springgreen'
colorffb='tab:green'
colorpri='tab:grey'
lw2=2
lw1=2
case=22
#le cas 8 a des observations relou.
foldname='results/'
obs=pd.DataFrame(data=np.loadtxt(foldname+'/obs/obs'+str(case)+'.gnu'),columns=['x','y','incx','incy'])


pfmp=pd.DataFrame(data=np.loadtxt(foldname+'fmp_imported/preds'+str(case)+'.gnu'),columns=['x','fzmean','fzstd','fzstd2','s1','s2','s3','s4','s5','s6','s7','s8','s9','s10'])
pFfmp=pd.DataFrame(data=np.loadtxt(foldname+'fmp_imported/predsF'+str(case)+'.gnu'),columns=['x','fmean','q1','q2','q2p5','q97p5'])



fig,axs=plt.subplots(nrows=1,ncols=2,figsize=(10,6))



#axs[1].plot(pfb['x'],sampFfmp['s1'],linewidth=1.5,color='tab:red',zorder=0,alpha=0.8,label=r'samples')
axs[1].plot(pfb['x'],pFfmp['fmean'],linewidth=lw2,linestyle='-.',color='tab:blue',label=r'posterior mean')
axs[1].plot(pfb['x'],pFfmp['q97p5'],linewidth=lw1,linestyle='--',color='tab:blue',label=r'95$\%$ credible interval')
axs[1].plot(pfb['x'],pFfmp['q2p5'],linewidth=lw1,linestyle='--',color='tab:blue')
axs[1].fill_between(pFfmp['x'],pFfmp['q2p5'],pFfmp['q97p5'],color='tab:blue',alpha=0.3)


#axs[0].plot(pfmp['x'],sampFfmp['s1'],linewidth=1.5,color='tab:red',zorder=0,alpha=0.8,label=r'samples')
axs[0].plot(pfmp['x'],pfmp['fzmean'],linewidth=lw2,linestyle='-.',color='tab:blue',label=r'posterior mean')
axs[0].plot(pfmp['x'],pfmp['fzmean']+2*pfmp['fzstd'],linewidth=lw1,linestyle='--',color='tab:blue',label=r'95$\%$ credible interval')
axs[0].plot(pfmp['x'],pfmp['fzmean']-2*pfmp['fzstd'],linewidth=lw1,linestyle='--',color='tab:blue')

axs[0].fill_between(pfmp['x'],pfmp['fzmean']-2*pfmp['fzstd'],pfmp['fzmean']+2*pfmp['fzstd'],color='tab:blue',alpha=0.3)

ls=['s4','s5','s6']
#ls=['s5']

#for s in ls:
#    axs[1].plot(pfb['x'],sampFfmp[s],linewidth=1.5,color='tab:red',zorder=0,alpha=0.3)
#    axs[0].plot(pfmp['x'],sampFfmp[s]+sampZfmp[s],linewidth=1.5,color='tab:red',zorder=0,alpha=0.3)
 
axs[0].errorbar(obs['x'],obs['y'],xerr=3*obs['incx'],
             color='tab:red',marker='o',ms=6,mfc='white',
             capsize=5,capthick=3,linewidth=0,elinewidth=3,
             label='observations',zorder=100)

axs[1].errorbar(obs['x'],obs['y'],xerr=3*obs['incx'],
             color='tab:red',marker='o',ms=6,mfc='white',
             capsize=5,capthick=3,linewidth=0,elinewidth=3,
             label='observations',zorder=100)

for ax2 in axs:
    ax2.yaxis.offsetText.set_visible(False)

offset = axs[0].yaxis.get_major_formatter().get_offset()

axs[0].set_xlim([0,35])
axs[0].set_ylim([0,obs['y'][len(obs['y'])-1]+3*obs['incy'][len(obs['y'])-1]+1e6])
axs[0].set_xlabel('Wall superheat $[K]$ ')
axs[0].yaxis.set_label_text(r'Heat flux $[W.m^{-2}] \times 10^6$')
axs[0].set_title('Predictions with \n'+r'$f+z_\theta$, case '+str(case),fontsize=25)

axs[1].set_xlim([0,35])
axs[1].set_ylim([0,obs['y'][len(obs['y'])-1]+3*obs['incy'][len(obs['y'])-1]+1e6])
axs[1].set_xlabel('Wall superheat $[K]$')
#axs[1].set_ylabel('Heat flux $[W.m^{-2}]$')
axs[1].set_title('Predictions with \n'+r'$f$, case '+str(case),fontsize=25)
#print(obs)
plt.tight_layout()

nom=pd.DataFrame(data=np.loadtxt('results/cnom'+str(case)+'.gnu'),columns=['x','pred'])
axs[1].plot(nom['x'],nom['pred'],linestyle='-',color='black',label='without calibration',lw=2)


axs[0].legend(fontsize=15)
axs[1].legend(fontsize=15)

#print les hpars koh pooled
#ls=['s5']
#cases=['4','5','6','15','18','20','21','22']# ceux qui sont bons.

axs[0].tick_params(axis='both', labelsize=20)
axs[1].tick_params(axis='both', labelsize=20)
