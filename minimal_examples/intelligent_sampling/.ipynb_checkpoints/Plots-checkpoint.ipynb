# %% [raw]
# calcul de simples histogrammes pour le moment. afficher les densités des samples KOH Opt Bayes sur l'exemple de l'article 1.

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

mpl.rcParams['font.weight']='normal'

mpl.rcParams['font.size']=16 #10 #16 pour posts
mpl.rcParams['legend.fontsize']=12 #10 12 pour posts
#inline backend pour voir les figures dans le frontend notebook https://ipython.readthedocs.io/en/stable/interactive/plotting.html

# %%
fname='results/'


sampkoh=pd.DataFrame(data=np.loadtxt(fname+"sampkoh.gnu"),columns=['t1','edm','exp','lcor'])
sampopt=pd.DataFrame(data=np.loadtxt(fname+"sampopt.gnu"),columns=['t1','edm','exp','lcor'])
sampfb=pd.DataFrame(data=np.loadtxt(fname+"sampbayes.gnu"),columns=['t1','edm','exp','lcor'])
sampopt2=pd.DataFrame(data=np.loadtxt(fname+"resamples.gnu"),columns=['t1'])

# %%
nbins=40
xlim=[-0.5,1.5]
ylim=[0,9]
#plot d'histogrammes
fig,axs=plt.subplots(figsize=[14,4],ncols=3,nrows=1,sharey=True)
axs[0].hist(sampfb['t1'],bins=nbins,density=True,color='tab:blue',rwidth=0.7,label='Bayes')
axs[1].hist(sampkoh['t1'],bins=nbins,density=True,color='tab:red',rwidth=0.7)
axs[2].hist(sampopt['t1'],bins=nbins,density=True,color='black',rwidth=0.7)
axs[0].set_ylim(ylim)
axs[0].set_xlim(xlim)
axs[1].set_xlim(xlim)
axs[2].set_xlim(xlim)
plt.tight_layout()

# %%
#affichage de la distribution des poids
weights=pd.DataFrame(data=np.loadtxt(fname+"weights.gnu"),columns=['t1','w'])
res1=pd.DataFrame(data=np.loadtxt(fname+"resamples0.gnu"),columns=['t1'])
res2=pd.DataFrame(data=np.loadtxt(fname+"resamples1.gnu"),columns=['t1'])
res3=pd.DataFrame(data=np.loadtxt(fname+"resamples2.gnu"),columns=['t1'])
res4=pd.DataFrame(data=np.loadtxt(fname+"resamples3.gnu"),columns=['t1'])
res5=pd.DataFrame(data=np.loadtxt(fname+"resamples4.gnu"),columns=['t1'])

# %%
nbins=35
fig,axs=plt.subplots(figsize=[14,7],ncols=3,nrows=2)
ylim=[0,9]
axs[0,0].scatter(weights['t1'],weights['w'],color='black')
axs[0,1].hist(res1['t1'],bins=nbins,density=True,rwidth=0.6,color='black')
axs[0,2].hist(res2['t1'],bins=nbins,density=True,rwidth=0.6,color='black')
axs[1,0].hist(res3['t1'],bins=nbins,density=True,rwidth=0.6,color='black')
axs[1,1].hist(res4['t1'],bins=nbins,density=True,rwidth=0.6,color='black')
axs[1,2].hist(res5['t1'],bins=nbins,density=True,rwidth=0.6,color='black')

axs[0,0].set_ylim([0,15e4])
axs[0,1].set_ylim(ylim)
axs[0,2].set_ylim(ylim)
axs[1,0].set_ylim(ylim)
axs[1,1].set_ylim(ylim)
axs[1,2].set_ylim(ylim)

plt.tight_layout()

# %%
# Out:
# 1.4651162790697674

# %%
# Out:
# (0.0, 1.2)

# %%
# Out:
# [   0    1    2 ... 9997 9998 9999]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-436-d2713f5dc87f> in <module>
# ----> 1 df=pd.DataFrame(summary['nobs'].drop_duplicates())
#       2
#       3 #paramètres de traçage
#       4 edmmin=0.05
#       5 edmmax=0.15
#
# NameError: name 'summary' is not defined

# %%
#affichage d'une loi inverse-gamma pour illustrer
from scipy.stats import invgamma
a=5
b=0.4 #ou 1/0.4 ?
fig, ax = plt.subplots(1, 1)
x = np.linspace(invgamma.ppf(0.0001, a,scale=b),invgamma.ppf(0.99, a,scale=b), 100)
ax.plot(x, invgamma.pdf(x, a,scale=b),'r-', lw=5, alpha=0.6, label='invgamma pdf')
plt.grid()
ax.set_xlabel(r'$l$')
ax.set_ylabel(r'$\mathrm{p}(l)$')
# Out:
# Text(0, 0.5, '$\\mathrm{p}(l)$')
