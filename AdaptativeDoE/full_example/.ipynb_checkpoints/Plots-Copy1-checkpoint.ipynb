# %% [raw]
# Afficher vraisemblance et postérieure. Voir si l'approximation est correcte.

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
nobs=50
#inline backend pour voir les figures dans le frontend notebook https://ipython.readthedocs.io/en/stable/interactive/plotting.html
#observations=pd.DataFrame(data=np.loadtxt('results/observations.gnu'),columns=['x','obs']) #dataframe qui contient les observations sur lesquelles on travaille
gp=pd.DataFrame(data=np.loadtxt('results/gp.gnu'),columns=['x','mean']) //0.9
gp2=pd.DataFrame(data=np.loadtxt('results/gp2.gnu'),columns=['x','mean']) //-0.1
gp3=pd.DataFrame(data=np.loadtxt('results/gp3.gnu'),columns=['x','mean']) //0.5
ei=pd.DataFrame(data=np.loadtxt('results/EIprob.gnu'),columns=['theta','ei'])

print(gp)
print(np.loadtxt('results/gp.gnu'))
print(ei)
# Out:
#        x  mean
# 0    0.0   0.0
# 1    1.0   1.0
# 2    0.0   1.0
# 3    0.0   0.0
# 4    0.0   0.0
# ..   ...   ...
# 195  0.0   0.0
# 196  0.0   0.0
# 197  0.0   0.0
# 198  0.0   0.0
# 199  0.0   0.0
#
# [200 rows x 2 columns]
# [[0.2174342  0.1208618 ]
#  [0.9285523  1.038073  ]
#  [0.8613832  0.966454  ]
#  [0.07140052 0.03248667]
#  [0.6726524  0.7136504 ]
#  [0.391177   0.3083388 ]
#  [0.4229874  0.3501308 ]
#  [0.7746013  0.8576953 ]
#  [0.2941059  0.1939876 ]
#  [0.9861513  1.088969  ]
#  [0.4794976  0.4283887 ]
#  [0.6882576  0.7364671 ]
#  [0.03967968 0.02287578]
#  [0.6492938  0.6791701 ]
#  [0.7847622  0.8712227 ]
#  [0.8906147  0.9991323 ]
#  [0.3085124  0.2095371 ]
#  [0.8405387  0.9418413 ]
#  [0.1804993  0.0918974 ]
#  [0.2517229  0.1514824 ]
#  [0.06378811 0.02985973]
#  [0.5566538  0.5409776 ]
#  [0.3578659  0.266686  ]
#  [0.5010124  0.459263  ]
#  [0.2598717  0.1592658 ]
#  [0.2374592  0.138321  ]
#  [0.5290246  0.5001262 ]
#  [0.8457979  0.9481494 ]
#  [0.7507463  0.8252441 ]
#  [0.581903   0.5786076 ]
#  [0.05212067 0.02622592]
#  [0.1932565  0.1014169 ]
#  [0.7603007  0.8383529 ]
#  [0.6394883  0.6646062 ]
#  [0.3895061  0.3061956 ]
#  [0.660854   0.696277  ]
#  [0.885157   0.9932011 ]
#  [0.3326111  0.2367183 ]
#  [0.221386   0.1242114 ]
#  [0.1879343  0.09738246]
#  [0.5940595  0.5967767 ]
#  [0.6446994  0.6723515 ]
#  [0.2028993  0.1089541 ]
#  [0.9344039  1.04371   ]
#  [0.8159477  0.9115119 ]
#  [0.6985946  0.7514623 ]
#  [0.8053643  0.8980569 ]
#  [0.0993953  0.04387727]
#  [0.7216171  0.7844557 ]
#  [0.1372119  0.06353192]
#  [0.9463833  1.054928  ]
#  [0.8005862  0.8919072 ]
#  [0.5091819  0.4711102 ]
#  [0.6016646  0.6081492 ]
#  [0.2876798  0.187227  ]
#  [0.8246495  0.9223973 ]
#  [0.5712161  0.5626567 ]
#  [0.8729836  0.9796873 ]
#  [0.7062349  0.7624768 ]
#  [0.4259809  0.3541554 ]
#  [0.13418    0.06177763]
#  [0.08811621 0.03896185]
#  [0.9033582  1.012665  ]
#  [0.5343564  0.5079738 ]
#  [0.350578   0.2578888 ]
#  [0.02338033 0.01930757]
#  [0.8572727  0.9616839 ]
#  [0.7301613  0.7965397 ]
#  [0.7992754  0.8902122 ]
#  [0.8333071  0.9330627 ]
#  [0.8802998  0.9878557 ]
#  [0.1113975  0.04958803]
#  [0.3958821  0.3144026 ]
#  [0.9944862  1.095458  ]
#  [0.2329708  0.1343031 ]
#  [0.1284547  0.05854914]
#  [0.0428467  0.02367717]
#  [0.6121725  0.6238597 ]
#  [0.08101579 0.03609294]
#  [0.9713622  1.076896  ]
#  [0.2962215  0.1962373 ]
#  [0.2273848  0.1293867 ]
#  [0.5798072  0.5754773 ]
#  [0.511087   0.4738819 ]
#  [0.1789124  0.09074956]
#  [0.4548003  0.3936268 ]
#  [0.997867   1.098025  ]
#  [0.00564522 0.01648351]
#  [0.6325093  0.6542161 ]
#  [0.7675253  0.8481676 ]
#  [0.06559199 0.03046396]
#  [0.00334452 0.01619794]
#  [0.6519335  0.683083  ]
#  [0.6091555  0.6193498 ]
#  [0.9656172  1.072017  ]
#  [0.9832404  1.086648  ]
#  [0.6292435  0.6493483 ]
#  [0.01552781 0.01792111]
#  [0.4068048  0.3286409 ]
#  [0.758596   0.8360246 ]
#  [0.8779048  0.9851972 ]
#  [0.8357858  0.9360851 ]
#  [0.5858455  0.584498  ]
#  [0.01335676 0.01757594]
#  [0.4844326  0.4354255 ]
#  [0.3167092  0.2186213 ]
#  [0.1434982  0.06726734]
#  [0.5689599  0.559293  ]
#  [0.6214111  0.6376616 ]
#  [0.4358498  0.3675275 ]
#  [0.8953659  1.00423   ]
#  [0.9087509  1.018256  ]
#  [0.700823   0.7546811 ]
#  [0.658866   0.6933407 ]
#  [0.2471696  0.1472166 ]
#  [0.07964661 0.03555981]
#  [0.3813314  0.2957901 ]
#  [0.4439639  0.3786369 ]
#  [0.3660696  0.2767282 ]
#  [0.4319031  0.362161  ]]
#            x        ei
# 0  -0.289742  203.5177
# 1   0.997141  187.8898
# 2  -0.320945  203.1544
# 3   1.409133    0.0000
# 4   1.428378    0.0000
# ..       ...       ...
# 65 -0.353494  202.8234
# 66 -0.486079  201.5140
# 67  1.482900    0.0000
# 68 -0.436786  202.1044
# 69  0.539703  201.2722
#
# [70 rows x 2 columns]

# %%
def f(x,theta):
    return np.sin(x*theta*2)*x+(x+0.15)*(1-theta)

thetaaff=-0.1
X=np.linspace(0,1,500)

plt.figure(figsize=[13,18])
ax=plt.subplot(311)

plt.plot(X,f(X,thetaaff),color='black',linewidth=2.5,label='modèle correct')
plt.scatter('x','mean',data=gp2,label='Prédiction moyenne',color='tab:blue')
plt.grid()
plt.legend()
plt.xlabel('x')
plt.ylabel('f(x)')

ax=plt.subplot(312)
plt.scatter('theta','ei',data=ei,label='Expected Improvement',color='tab:red')
plt.grid()
plt.legend()
plt.xlabel('x')
plt.ylabel('EI')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-e026cb98b06e> in <module>
#      16
#      17 ax=plt.subplot(312)
# ---> 18 plt.scatter('theta','ei',data=ei,label='Expected Improvement',color='tab:red')
#      19 plt.grid()
#      20 plt.legend()
#
# ~/miniconda3/envs/snowflakes_env/lib/python3.7/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2814         verts=verts, edgecolors=edgecolors,
#    2815         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2816         None else {}), **kwargs)
#    2817     sci(__ret)
#    2818     return __ret
#
# ~/miniconda3/envs/snowflakes_env/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1589                 args_and_kwargs.get(label_namer), auto_label)
#    1590
# -> 1591         return func(*new_args, **new_kwargs)
#    1592
#    1593     inner.__doc__ = _add_data_doc(inner.__doc__, replace_names)
#
# ~/miniconda3/envs/snowflakes_env/lib/python3.7/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# ~/miniconda3/envs/snowflakes_env/lib/python3.7/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4389         y = np.ma.ravel(y)
#    4390         if x.size != y.size:
# -> 4391             raise ValueError("x and y must be the same size")
#    4392
#    4393         if s is None:
#
# ValueError: x and y must be the same size

# %%
def f(x):
    return np.sin(x)*x

X=np.linspace(0,10,500)

plt.figure(figsize=[13,9])
ax=plt.subplot(211)

plt.plot(X,f(X),color='black',linewidth=2.5,label='g(x)= x sin(x)')
plt.plot('x','mean',data=gp,label='Prédiction moyenne',color='tab:blue')
ax.fill_between('x','mean','low',data=gp,alpha=0.4,color='tab:blue',label='')
ax.fill_between('x','mean','up',data=gp,alpha=0.4,color='tab:blue',label='Intervalles de confiance 1sigma')
ax.scatter(x='x',y='obs',label='observations',data=observations[0:nobs],marker='+',linewidth=4,color='tab:red')
plt.grid()
plt.legend()
plt.xlabel('x')
plt.ylabel('f(x)')
ax=plt.subplot(212)

plt.plot('x','EI',data=gp,label='Expected Improvement',color='tab:red')
plt.grid()
plt.legend()
plt.xlabel('x')
plt.ylabel('EI')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-99f9e3e228f9> in <module>
#      11 ax.fill_between('x','mean','low',data=gp,alpha=0.4,color='tab:blue',label='')
#      12 ax.fill_between('x','mean','up',data=gp,alpha=0.4,color='tab:blue',label='Intervalles de confiance 1sigma')
# ---> 13 ax.scatter(x='x',y='obs',label='observations',data=observations[0:nobs],marker='+',linewidth=4,color='tab:red')
#      14 plt.grid()
#      15 plt.legend()
#
# NameError: name 'observations' is not defined
