# %%
#affichage des résultats de calibration. Prédictions et densités à posteriori.
#Prédictions Ravik.
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
# %matplotlib inline

# %%
foldname='Calibration_Ravik_MCMC_multiple/results/'
burn1=pd.DataFrame(data=np.loadtxt(foldname+'burn1.gnu'),columns=['t1','t2','t3'])
burn2=pd.DataFrame(data=np.loadtxt(foldname+'burn2.gnu'),columns=['t1','t2','t3'])
burn3=pd.DataFrame(data=np.loadtxt(foldname+'burn3.gnu'),columns=['t1','t2','t3'])
burn4=pd.DataFrame(data=np.loadtxt(foldname+'burn4.gnu'),columns=['t1','t2','t3'])
burn5=pd.DataFrame(data=np.loadtxt(foldname+'burn5.gnu'),columns=['t1','t2','t3'])
burn6=pd.DataFrame(data=np.loadtxt(foldname+'burn6.gnu'),columns=['t1','t2','t3','ll'])
burn7=pd.DataFrame(data=np.loadtxt(foldname+'burn7.gnu'),columns=['t1','t2','t3','ll'])
burn8=pd.DataFrame(data=np.loadtxt(foldname+'burn8.gnu'),columns=['t1','t2','t3','ll'])
xlim=[0,1]

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot3D(burn1['t1'],burn1['t2'],burn1['t3'])
ax.set_xlabel('t1')
ax.set_ylabel('t2')
ax.set_zlabel('t3')
ax.set_xlim(xlim)
ax.set_ylim(xlim)
ax.set_zlim(xlim)
# Out:
# (0.0, 1.0)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot3D(burn2['t1'],burn2['t2'],burn2['t3'])
ax.set_xlim(xlim)
ax.set_ylim(xlim)
ax.set_zlim(xlim)
# Out:
# (0.0, 1.0)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot3D(burn3['t1'],burn3['t2'],burn3['t3'])
ax.set_xlim(xlim)
ax.set_ylim(xlim)
ax.set_zlim(xlim)
# Out:
# (0.0, 1.0)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot3D(burn4['t1'],burn4['t2'],burn4['t3'])
ax.set_xlim(xlim)
ax.set_ylim(xlim)
ax.set_zlim(xlim)
# Out:
# (0.0, 1.0)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot3D(burn5['t1'],burn5['t2'],burn5['t3'])
ax.set_xlim(xlim)
ax.set_ylim(xlim)
ax.set_zlim(xlim)
# Out:
# (0.0, 1.0)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot3D(burn6['t1'],burn6['t2'],burn6['t3'])
ax.set_xlim(xlim)
ax.set_ylim(xlim)
ax.set_zlim(xlim)
# Out:
# (0.0, 1.0)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot3D(burn7['t1'],burn7['t2'],burn7['t3'])
ax.set_xlim(xlim)
ax.set_ylim(xlim)
ax.set_zlim(xlim)
# Out:
# (0.0, 1.0)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot3D(burn8['t1'],burn8['t2'],burn8['t3'])
ax.set_xlim(xlim)
ax.set_ylim(xlim)
ax.set_zlim(xlim)
# Out:
# (0.0, 1.0)

# %%
allsamp=np.loadtxt(foldname+'save/samplesopt.gnu')[:,0:3]
allsamp=pd.DataFrame(data=allsamp,columns=['t1','t2','t3'])
allsampkoh=np.loadtxt(foldname+'save/sampleskoh.gnu')[:,0:3]
allsampkoh=pd.DataFrame(data=allsampkoh,columns=['t1','t2','t3'])
allsampkohsep=np.loadtxt(foldname+'save/sampleskohsep.gnu')[:,0:3]
allsampkohsep=pd.DataFrame(data=allsampkohsep,columns=['t1','t2','t3'])

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot3D(allsamp['t1'],allsamp['t2'],allsamp['t3'])
ax.set_xlim(xlim)
ax.set_ylim(xlim)
ax.set_zlim(xlim)
print(allsamp)
# Out:
#            t1        t2        t3
# 0    0.250096  0.183123  0.811646
# 1    0.326747  0.070282  0.805756
# 2    0.346350  0.142328  0.783263
# 3    0.355941  0.159849  0.787425
# 4    0.684417  0.055343  0.658682
# ..        ...       ...       ...
# 194  0.350428  0.112305  0.775957
# 195  0.290552  0.159459  0.809762
# 196  0.439802  0.061710  0.798312
# 197  0.287331  0.132884  0.829047
# 198  0.395405  0.052466  0.818540
#
# [199 rows x 3 columns]

# %%
#sampleskoh vient du problème koh séparé avec un MCMC classique.
#On constate que l'espace des paramètres est bcp plus restreint que la méthode Opt.
#Question : est-ce dû à mon algo MCMC ? j'essaye l'algo adapt, et les résultats sont dans sampleskohsep.
#Et aussi : est-ce que le problème KOH couplé devient soluble avec el nouvel algo MCMC ? Est-ce que la solution ressemble à Opt ?
# On peut rêver : est-ce que Bayes est faisable avec leur nouvel algo ?
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot3D(allsampkoh['t1'],allsampkoh['t2'],allsampkoh['t3'])
ax.set_xlim(xlim)
ax.set_ylim(xlim)
ax.set_zlim(xlim)
print(allsampkoh)
# Out:
#            t1        t2        t3
# 0    0.680332  0.947342  0.231743
# 1    0.690117  0.966750  0.202581
# 2    0.678066  0.992082  0.205222
# 3    0.681523  0.929657  0.226846
# 4    0.673670  0.983469  0.203493
# ..        ...       ...       ...
# 194  0.697821  0.917741  0.226471
# 195  0.691340  0.980882  0.205571
# 196  0.756981  0.651295  0.312752
# 197  0.659566  0.988346  0.217692
# 198  0.668297  0.986226  0.210900
#
# [199 rows x 3 columns]

# %%
#sampleskoh vient du problème koh séparé avec un MCMC classique.
#On constate que l'espace des paramètres est bcp plus restreint que la méthode Opt.
#Question : est-ce dû à mon algo MCMC ? j'essaye l'algo adapt, et les résultats sont dans sampleskohsep.
#Et aussi : est-ce que le problème KOH couplé devient soluble avec el nouvel algo MCMC ? Est-ce que la solution ressemble à Opt ?
# On peut rêver : est-ce que Bayes est faisable avec leur nouvel algo ?
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot3D(allsampkohsep['t1'],allsampkohsep['t2'],allsampkohsep['t3'])
ax.set_xlim(xlim)
ax.set_ylim(xlim)
ax.set_zlim(xlim)
print(allsampkohsep)
# Out:
#            t1        t2        t3
# 0    0.678073  0.980940  0.214099
# 1    0.659944  0.955013  0.233980
# 2    0.682061  0.909379  0.235817
# 3    0.682664  0.944139  0.220963
# 4    0.705651  0.982828  0.197459
# ..        ...       ...       ...
# 194  0.668571  0.845537  0.271041
# 195  0.697799  0.997965  0.198336
# 196  0.718907  0.986725  0.184352
# 197  0.669388  0.894795  0.255057
# 198  0.691027  0.999255  0.184071
#
# [199 rows x 3 columns]

# %%
#fonctions pour afficher une prédiction et les observations correspondantes.

def show_preds(predfile,obsfile,xlim):
    obs=pd.DataFrame(data=np.loadtxt(obsfile),columns=['x','y'])
    pred=pd.DataFrame(data=np.loadtxt(predfile),columns=['x','ymean','q25','q75','q2p5','q97p5','ymap'])#pas sûr que ymap soit en dernière poisition ou en seconde.
    plt.figure(figsize=(6,6))
    fig,ax1=plt.subplots(nrows=1,ncols=1,figsize=(6,6))
    ax1.scatter(obs['x'],obs['y'],marker='+',color='tab:red')
    ax1.plot(pred['x'],pred['ymean'],color='tab:green')
    ax1.fill_between(pred['x'],pred['q2p5'],pred['q97p5'],color='tab:blue',alpha=0.2)
    ax1.set_xlim(xlim)
    plt.grid()
    plt.show()
    
def show_predsFZ(predfile,obsfile,xlim):
    obs=pd.DataFrame(data=np.loadtxt(obsfile),columns=['x','y'])
    pred=pd.DataFrame(data=np.loadtxt(predfile),columns=['x','mean','std','stdz','s1','s2','s3','s4','s5','s6','s7','s8','s9','s10'])#pas sûr que ymap soit en dernière poisition ou en seconde.
    plt.figure(figsize=(6,6))
    fig,ax1=plt.subplots(nrows=1,ncols=1,figsize=(6,6))
    ax1.scatter(obs['x'],obs['y'],marker='+',color='tab:red')
    ax1.fill_between(pred['x'],pred['mean']-3*pred['std'],pred['mean']+3*pred['std'],color='tab:blue',alpha=0.2)
    ax1.plot(pred['x'],pred['mean'],color='tab:blue')
    ax1.set_xlim(xlim)
    plt.grid()
    plt.show()

xlim=[0,30]
#correspondances : cases={3,4,5,6,14,15,16,18,20,21,22,23};
predname=foldname+'preds/predopt4.gnu'
predname2=foldname+'preds/predoptF4.gnu'
obsname=foldname+'obs14.gnu'
show_predsFZ(predname,obsname,xlim)
show_preds(predname2,obsname,xlim)

# %%
#affichage des prédictions avec fit_gp
fn='test_fit_gp/results/'
obs=pd.DataFrame(data=np.loadtxt(fn+'obs3.gnu'),columns=['x','obs'])
pred=pd.DataFrame(data=np.loadtxt(fn+'preds.gnu'),columns=['x','mean','3sd','s1','s2','s3'])
fig,ax1=plt.subplots(nrows=1,ncols=1,figsize=(6,6))
ax1.plot(pred['x'],pred['mean'],color='tab:green')

ax1.plot(pred['x'],pred['s1'],color='black')
ax1.plot(pred['x'],pred['s2'],color='black')
ax1.plot(pred['x'],pred['s3'],color='black')
ax1.fill_between(pred['x'],pred['mean']+pred['3sd'],pred['mean']-pred['3sd'],color='tab:green',alpha=0.2)
ax1.scatter(obs['x'],obs['obs'],marker='+',color='tab:red')
ax1.set_xlim(xlim)
plt.grid()
plt.show()
